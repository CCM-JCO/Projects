# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir('C:/Users/memdp/PYTHON_CODE/Datasets')
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.histplot(x=df.Age, y=df.BMI)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='BMI'>

# %%
"""
The majority of participants
"""
count=0
for x in df.Age:
    if x < 30:
        count += 1

print(count)
"""
Saving a png file containing the histogram and
a vertical line running through the mean and median
of the AGE feature in the dataset.

This is of importance to determine the age category
where most applicants fall under. 

We can determine bias or underrepresentations in 
the dataset early on by looking
at this particular feature.
"""
sns.set(rc={'figure.figsize':(15,10)})
ax = sns.histplot(data=df, x=df.Age)
ax.set(xlabel='Age', ylabel='Number of individuals')

plt.title('Age groups based on number of individuals', fontsize=20)
plt.axvline(df.Age.mean(), color='k', linestyle='dashed', label='mean')
plt.axvline(df.Age.median(), color='r', linestyle='dashed', label='median')
plt.legend(prop={'size': 17})
plt.savefig('C:/Users/memdp/PYTHON_CODE/Figures/AGE_histogram.png')


print(f'Age median: {df.Age.median()}')
print(f'Age mean: {round(df.Age.mean(), 2)}')

# print(f'Age < 30 count: {}')
# Out:
# 396
# Age median: 29.0
# Age mean: 33.24

# %%
sns.set(rc={'figure.figsize':(15,10)})
ax = sns.histplot(data=df, x=df.Pregnancies, bins=17)
ax.set(xlabel='Pregnancies', ylabel='# of individuals')

plt.title('Histogram of individual(s) with number of pregnancies', fontsize=20)
plt.axvline(df.Pregnancies.mean(), color='k', linestyle='dashed', label='mean')
plt.axvline(df.Pregnancies.median(), color='r', linestyle='dashed', label='median')
plt.legend(prop={'size': 17})
plt.savefig('C:/Users/memdp/PYTHON_CODE/Figures/Pregnancies_histogram.png')

# %%
"""
BMI mean is roughly equal to the 
BMI median, since there are not
many outliers.

The average BMI is 32, which means most 
people can be categorized as obese. This
makes sense given the people who parti-
cipated.
"""
sns.set(rc={'figure.figsize':(15,10)})
ax = sns.histplot(data=df, x=df.BMI)
ax.set(xlabel='BMI', ylabel='# of individuals')
plt.title('Histogram of individual(s) with BMI', fontsize=20)
plt.savefig('C:/Users/memdp/PYTHON_CODE/Figures/BMI_histogram.png')
print(f'BMI median: {df.BMI.median()}')
print(f'BMI mean: {round(df.BMI.mean(),2)}')
# Out:
# BMI median: 32.0
# BMI mean: 31.99

# %%
"""
The average features related to the number of pregnancies.
For instance people who have never been pregnant on average
have a BMI of 34.29 and are on average 27.6 years of age.
"""
df_pregnancies = df.groupby(['Pregnancies']).mean()
df_pregnancies
# Out:
#                 Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Pregnancies
# 0            123.000000      67.153153      22.270270   81.675676  34.290090
# 1            112.748148      67.792593      24.437037   98.674074  31.372593
# 2            110.796117      63.252427      21.601942   85.844660  30.583495
# 3            123.586667      66.586667      20.080000   87.453333  30.425333
# 4            125.117647      70.029412      15.882353   69.441176  32.141176
# 5            118.859649      76.210526      17.385965   57.298246  33.192982
# 6            120.800000      68.420000      17.640000   63.580000  30.290000
# 7            136.444444      70.777778      20.288889   84.466667  32.631111
# 8            131.736842      75.184211      17.315789   92.815789  31.568421
# 9            131.392857      77.892857      20.892857   62.428571  31.707143
# 10           120.916667      70.208333      15.708333   34.791667  30.641667
# ...

# %%
print(f'Max amount of pregnancies: {df.Pregnancies.max()}\n')
print(f'Min amount of pregnancies: {df.Pregnancies.min()}\n')
for x in range(18):
    print(f'Pregnant {x} time(s): {df[df.Pregnancies == x].shape[0]}')
# Out:
# Max amount of pregnancies: 17
#
# Min amount of pregnancies: 0
#
# Pregnant 0 time(s): 111
# Pregnant 1 time(s): 135
# Pregnant 2 time(s): 103
# Pregnant 3 time(s): 75
# Pregnant 4 time(s): 68
# Pregnant 5 time(s): 57
# Pregnant 6 time(s): 50
# Pregnant 7 time(s): 45
# Pregnant 8 time(s): 38
# Pregnant 9 time(s): 28
# Pregnant 10 time(s): 24
# Pregnant 11 time(s): 11
# Pregnant 12 time(s): 9
# Pregnant 13 time(s): 10
# Pregnant 14 time(s): 2
# Pregnant 15 time(s): 1
# Pregnant 16 time(s): 0
# Pregnant 17 time(s): 1

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(df.iloc[:, 0:8], df.iloc[:, 8])
clf.support_vectors_
# Out:
# array([[5.00e+00, 1.16e+02, 7.40e+01, ..., 2.56e+01, 2.01e-01, 3.00e+01],
#        [1.00e+01, 1.15e+02, 0.00e+00, ..., 3.53e+01, 1.34e-01, 2.90e+01],
#        [4.00e+00, 1.10e+02, 9.20e+01, ..., 3.76e+01, 1.91e-01, 3.00e+01],
#        ...,
#        [0.00e+00, 1.23e+02, 7.20e+01, ..., 3.63e+01, 2.58e-01, 5.20e+01],
#        [9.00e+00, 1.70e+02, 7.40e+01, ..., 4.40e+01, 4.03e-01, 4.30e+01],
#        [1.00e+00, 1.26e+02, 6.00e+01, ..., 3.01e+01, 3.49e-01, 4.70e+01]])

# %%
# Reporting the status of fitting, 0 means correctly fitted
clf.fit_status_
# Out:
# 0

# %%
# Reporting the number of features in the dataset
clf.n_features_in_
# Out:
# 8

# %%
"""
Using the prediction function to determine if a 
person is diabetic based on the features data uses.
"""
print(clf.predict([[2,148,72,35,0,33.6,0.627,23]]))
# Out:
# [1]

# %%
# Suppose we choose to remove labels(outcome) from the correlation plot
df_2 = pd.DataFrame(df.iloc[:, 0:8])
df_2.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# ...

# %%
"""
Heatmap of the correlation matrix of the dataset.
We can visualize the intensity of correlation that 
the features have with one another.

For instance, Age and Pregnancy are positively correlated
with strong correlation, > 0.5

Insulin and SkinThickness are positively correlated with 
a correlation of 0.44
"""
sns.heatmap(df.corr(),linewidths=5, cmap='YlGnBu', annot=True)
# Out:
# <AxesSubplot:>

# %%
"""
Looking at the level of which features X, Y vary together.
"""
df.cov()
# Out:
#                           Pregnancies      Glucose  BloodPressure  \
# Pregnancies                 11.354056    13.947131       9.214538
# Glucose                     13.947131  1022.248314      94.430956
# BloodPressure                9.214538    94.430956     374.647271
# SkinThickness               -4.390041    29.239183      64.029396
# Insulin                    -28.555231  1220.935799     198.378412
# BMI                          0.469774    55.726987      43.004695
# DiabetesPedigreeFunction    -0.037426     1.454875       0.264638
# Age                         21.570620    99.082805      54.523453
# Outcome                      0.356618     7.115079       0.600697
#
#                           SkinThickness       Insulin         BMI  \
# Pregnancies                   -4.390041    -28.555231    0.469774
# Glucose                       29.239183   1220.935799   55.726987
# BloodPressure                 64.029396    198.378412   43.004695
# ...
