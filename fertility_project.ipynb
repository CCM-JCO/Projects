# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir("C:/Users/memdp/PYTHON_CODE/Datasets")

column_names = ["Season", "Age", "Childish_Disease", "Accident/Trauma", "Surgery_Intervention", "High_Fevers",
                "Alcohol_Consumption", "Smoking_Habit", "Sedentary_Hours", "Diagnosis"]

"""
Note: 
        Usually 0 represents False, 1 represents true, However, here it's backwards
        for some features...
        
        Season:
                -1    == Winter
                -0.33 == Spring
                 0.33 == Summer
                 1    == Fall
                 
        Age: ???
                0 if Age is between 18-36
                1 otherwise
                
        Childish Disease:
                True -> 0
                False -> 1
                
        Accident/Trauma:
                True -> 0
                False -> 1
                
        Surgical Intervention:
                True -> 0
                False -> 1
                
        High Fevers in the last year:
                Less than 3 months ago == -1
                More than 3 months age ==  1
                None                   ==  0
        
        Freq of Alcohol Consumption:
                Several time a day/Every day/Several times a week/once a week == 0
                Hardly ever or never                                          == 1
        
        Smoking habit:
                Never        == -1
                Occasionally ==  0
                Daily        ==  1
                
        Sedentary hours: ???
                Greater than 16 == 0
                Less than 16    == 1
        
        Diagnosis:
                Normal  == N
                Altered == O
        
"""
dataframe = pd.read_csv("fertility_Diagnosis.txt", index_col=False, names=column_names)
dataframe
# Out:
#     Season   Age  Childish_Disease  Accident/Trauma  Surgery_Intervention  \
# 0    -0.33  0.69                 0                1                     1
# 1    -0.33  0.94                 1                0                     1
# 2    -0.33  0.50                 1                0                     0
# 3    -0.33  0.75                 0                1                     1
# 4    -0.33  0.67                 1                1                     0
# ..     ...   ...               ...              ...                   ...
# 95   -1.00  0.67                 1                0                     0
# 96   -1.00  0.61                 1                0                     0
# 97   -1.00  0.67                 1                1                     1
# 98   -1.00  0.64                 1                0                     1
# 99   -1.00  0.69                 0                1                     1
#
#     High_Fevers  Alcohol_Consumption  Smoking_Habit  Sedentary_Hours Diagnosis
# ...

# %%
winter = dataframe[dataframe.Season == -1].shape[0]
spring = dataframe[dataframe.Season == -0.33].shape[0]
summer = dataframe[dataframe.Season == 0.33].shape[0]
fall = dataframe[dataframe.Season == 1].shape[0]

"""
Most samples were taken during spring, which accounts for 37 samples.
Followed by 31 samples taken fall and 28 samples taken winter.

Only 4 samples were taken during the summer.
"""

outcome = ["winter", "spring", "summer", "fall"]
height = [winter, spring, summer, fall]

plt.figure(figsize=(15,10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
# Out:
# <BarContainer object of 4 artists>

# %%
yes = dataframe[dataframe.Childish_Disease == 0].shape[0]
no = dataframe[dataframe.Childish_Disease == 1].shape[0]

outcome = ['no', 'yes']
height = [no, yes]
plt.figure(figsize=(15,10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
plt.xticks(fontsize=20, fontweight="bold")
plt.ylabel("Frequency", fontsize=20)
plt.title("Childhood Disease",\
           fontsize=25, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Childhood Disease')

# %%
yes = dataframe[dataframe["Accident/Trauma"] == 0].shape[0]
no = dataframe[dataframe["Accident/Trauma"] == 1].shape[0]

height = [no, yes]
plt.figure(figsize=(15, 10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
plt.xticks(fontsize=20, fontweight="bold")
plt.ylabel("Frequency", fontsize=20)
plt.title("Accident/Serious Trauma", fontsize=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Accident/Serious Trauma')

# %%
yes = dataframe[dataframe.Surgery_Intervention == 0].shape[0]
no = dataframe[dataframe.Surgery_Intervention == 1].shape[0]

height = [no, yes]
plt.figure(figsize=(15, 10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
plt.xticks(fontsize=20, fontweight="bold")
plt.ylabel("Frequency", fontsize=20)
plt.title("Surgical Intervention", fontsize=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Surgical Intervention')

# %%
yes = dataframe[dataframe.High_Fevers == 0].shape[0]
no = dataframe[dataframe.High_Fevers == 1].shape[0]

height = [no, yes]
plt.figure(figsize=(15, 10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
plt.xticks(fontsize=20, fontweight="bold")
plt.ylabel("Frequency", fontsize=20)
plt.title("High Fevers", fontsize=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'High Fevers')

# %%
option_1 = dataframe[dataframe.Alcohol_Consumption == 0.2].shape[0]
option_2 = dataframe[dataframe.Alcohol_Consumption == 0.4].shape[0]
option_3 = dataframe[dataframe.Alcohol_Consumption == 0.6].shape[0]
option_4 = dataframe[dataframe.Alcohol_Consumption == 0.8].shape[0]
option_5 = dataframe[dataframe.Alcohol_Consumption == 1].shape[0]

outcome = ["Several times a day", "Every Day", "Several times a week",
           "Once a week", "Hardly ever or never"]
height = [option_1, option_2, option_3, option_4, option_5]
plt.figure(figsize=(15, 10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
plt.xticks(fontsize=10, fontweight="bold")
plt.ylabel("Frequency", fontsize=20)
plt.title("Alcohol Consumption", fontsize=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Alcohol Consumption')

# %%
never = dataframe[dataframe.Smoking_Habit == -1].shape[0]
occasionally = dataframe[dataframe.Smoking_Habit == 0].shape[0]
daily = dataframe[dataframe.Smoking_Habit == 1].shape[0]

outcome = ["Never", "Occasionally", "Daily"]
height = [never, occasionally, daily]

plt.figure(figsize=(15, 10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
plt.xticks(fontsize=20, fontweight="bold")
plt.ylabel("Frequency", fontsize=20)
plt.title("Smoking Habit", fontsize=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Smoking Habit')

# %%
sns.set(rc={"figure.figsize":(15,10)})
ax2 = sns.histplot(dataframe.Sedentary_Hours, kde=True, color="thistle",
                  edgecolor="fuchsia")
ax2.set_title("Sedentary Hours", fontsize=25, fontweight="bold")
ax2.set_xlabel("")
ax2.set_ylabel("Frequency", fontsize=20)
ax2.tick_params(labelsize=20)

# %%
# Out:
# Text(0.5, 1.0, 'Diagnosis')

# %%
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

dataframe.Diagnosis = dataframe.Diagnosis.replace('O', 1)
dataframe.Diagnosis = dataframe.Diagnosis.replace('N', 0)

X = dataframe.iloc[:, 0:9]
y = dataframe.iloc[:, 9]

"""
Default split is 75% training and 25% testing data split.
"""
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=0)
clf_logistic = LogisticRegression()
clf_svc_linear = SVC(kernel="linear", C=0.025)
clf_svc_gamma = SVC(gamma=2, C=1)
clf_qda = QuadraticDiscriminantAnalysis()
clf_lda = LinearDiscriminantAnalysis()


clf_logistic.fit(X_train, y_train)
clf_svc_linear.fit(X_train, y_train)
clf_svc_gamma.fit(X_train, y_train)
clf_qda.fit(X_train, y_train)
clf_lda.fit(X_train, y_train)

# predictions_logistic = clf_logistic.predict(X_test)
# predictions_svc_linear = clf_svc_linear.predict(X_test)
# predictions_svc_gamma = clf_svc_gamma.predict(X_test)
# predictions_qda = clf_qda.predict(X_test)
# predictions_lda = clf_lda.predict(X_test)


print("Logistic Regression Score:", clf_logistic.score(X_test, y_test))
print("QDA Score:", clf_qda.score(X_test, y_test))
# print("SVM linear Score:", clf_svc_linear.score(X_test, y_test))
# print("SVM gamma Score:", clf_svc_gamma.score(X_test, y_test))
# print("QDA Score:", clf_qda.score(X_test y_test))
# print("LDA Score:", clf_lda.score(X_test, y_test))
print("The classifier with the highest score is Quadratic Discriminant Analysis.")
# Out:
# Logistic Regression Score: 0.92
# QDA Score: 0.92
# The classifier with the highest score is Quadratic Discriminant Analysis.

# %%
cm_logistic = metrics.confusion_matrix(y_test, predictions_logistic, labels=clf_logistic.classes_)
disp_logistic = metrics.ConfusionMatrixDisplay(confusion_matrix=cm_logistic,
                              display_labels=clf_logistic.classes_)

# fig, ax = plt.subplots(figsize=(15,10))
# disp_logistic.plot(ax=ax)
plt.savefig("ConfusionMatrixLogistic.png")

# %%
cm_qda = confusion_matrix(y_test, predictions_qda, labels=clf_qda.classes_)
disp_qda = ConfusionMatrixDisplay(confusion_matrix=cm_qda,
                              display_labels=clf_qda.classes_)

fig, ax = plt.subplots(figsize=(15,15))
disp_qda.plot(ax=ax)
plt.savefig("ConfusionMatrixQDA.png")

# %%
metrics.precision_recall_fscore_support(y_test, predictions_logistic,
                                        average='micro')
# Out:
# (0.92, 0.92, 0.92, None)

# %%
precision_qda = metrics.precision_score(y_test, predictions_qda, average="micro")
recall_qda = metrics.recall_score(y_test, predictions_qda, average="micro")
f1_qda = metrics.f1_score(y_test, predictions_qda, average="micro")

print(f"Precision/ % of samples labeled True that are really True.")
print(f"\tPrecision = {precision_qda}")

print(f"\nRecall/ % of True samples correctly labeled.")
print(f"\tRecall = {recall_qda}")

print(f"\nF1 score/ Approaches 1 as errors decline.")
print(f"\tRecall = {f1_qda}")
# Out:
# Precision/ % of samples labeled True that are really True.
# 	Precision = 0.92
#
# Recall/ % of True samples correctly labeled.
# 	Recall = 0.92
#
# F1 score/ Approaches 1 as errors decline.
# 	Recall = 0.92

# %%
"""
Normal == 0, since 0 is false, "no disease"

Altered == 1

Showing the bar plot of Diagnosis shows why our classifier
is not realiable. The frequency of Normal samples heavily
outweights Altered samples. This skews our classifier.

Our samples does not train our classifier to find many
Altered samples!!!
"""
Normal = dataframe[dataframe.Diagnosis == 0].shape[0]
Altered = dataframe[dataframe.Diagnosis == 1].shape[0]

outcome = ["N: Normal", "O: Altered"]
height = [Normal, Altered]

plt.figure(figsize=(15, 10))
plt.bar(outcome, height, color="thistle", edgecolor="fuchsia")
plt.xticks(fontsize=20, fontweight="bold")
plt.ylabel("Frequency", fontsize=20)
plt.title("Diagnosis", fontsize=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Diagnosis')

# %%
ax = pd.plotting.scatter_matrix(dataframe, figsize=(20,20), diagonal='kde');

# %%
def encode_and_bind(dataframe, feature):
    dummies = pd.get_dummies(dataframe[[feature]])
    res = pd.concat([dataframe, dummies], axis=1)
    res = res.drop([feature], axis=1)
    return(res)
encode_and_bind(dataframe, 'Diagnosis')
